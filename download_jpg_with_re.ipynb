# %% [markdown]
# ## Downloading Picture with RE

# %%
import requests
import urllib.request
import re

# %% [markdown]
# ### 1 define a function to retreive the data from a webpage

# %%
def get_html(url):
    ua_headers={'User-Agent':'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_8; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50'}
    request = urllib.request.Request(url,headers=ua_headers)
    html = requests.get(url, headers = ua_headers).text
    return html

# %% [markdown]
# ### 2 Let's see what we get
# It looks like that all the img source is in one format

# %%
content=get_html('https://movie.douban.com/subject/1851857/all_photos')
print(content)
# Out:
# <!DOCTYPE html>
# <html lang="zh-cmn-Hans" class="ua-mac ua-webkit">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit">
#     <meta name="referrer" content="always">
#     <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />
#     <title>
#   蝙蝠侠：黑暗骑士的全部图片
# </title>
#
#     <meta name="baidu-site-verification" content="cZdR4xxR7RxmM4zE" />
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">
#
#     <meta name="mobile-agent" content="format=html5; url=http://m.douban.com/movie/subject/1851857/all_photos"/>
#
#     <link rel="apple-touch-icon" href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png">
# ...

# %% [markdown]
# ### 3 RE is a good tool to regulize and extract information

# %%
reg = r'src="(.+?\.jpg)"'
reg_img = re.compile(reg)#编译一下，运行更快
imglist=reg_img.findall(content)
for img in imglist:
    print(img)
# Out:
# https://img3.doubanio.com/view/photo/sqxs/public/p457121714.jpg
# https://img1.doubanio.com/view/photo/sqxs/public/p457121168.jpg
# https://img3.doubanio.com/view/photo/sqxs/public/p462663754.jpg
# https://img1.doubanio.com/view/photo/sqxs/public/p1288252107.jpg
# https://img1.doubanio.com/view/photo/sqxs/public/p457121599.jpg
# https://img1.doubanio.com/view/photo/sqxs/public/p1024656669.jpg
# https://img3.doubanio.com/view/photo/sqxs/public/p457121785.jpg
# https://img3.doubanio.com/view/photo/sqxs/public/p457121826.jpg
# https://img3.doubanio.com/view/photo/sqxs/public/p939328126.jpg
# https://img1.doubanio.com/view/photo/sqxs/public/p457121708.jpg
# https://img3.doubanio.com/view/photo/sqxs/public/p1673865753.jpg
# https://img3.doubanio.com/view/photo/sqxs/public/p2260178846.jpg
# https://img1.doubanio.com/view/photo/sqxs/public/p457121738.jpg
# https://img1.doubanio.com/view/photo/sqxs/public/p1043646847.jpg
# https://img3.doubanio.com/view/photo/sqxs/public/p457121143.jpg
# ...

# %% [markdown]
# ### 4 Here we go :

# %%
x = 0
for img in imglist:
    urllib.request.urlretrieve(img, '%s.jpg' %x)
    x += 1
# Out:
#   File "<ipython-input-103-9784b1e98582>", line 3
#     urllib.request.urlretrieve(img, '%s.jpg' %"Batman-TDK"x)
#                                                           ^
# SyntaxError: invalid syntax
